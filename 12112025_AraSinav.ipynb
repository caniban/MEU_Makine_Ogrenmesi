# %% [markdown]
# # T.C. Mersin Üniversitesi - Mühendislik Fakültesi
# ## Harita Mühendisliği Bölümü - 1607013 Veri Bilimi Dersi
#
# ---
#
# ## Ara Sınav Soruları - 12 Kasım 2025
# ### Sınav Süresi: **70 Dakika**
#
# ---
#
# ### Öğretim Üyesi: **Doç. Dr. Muzaffer Can İBAN**
# ### E-posta: `caniban@mersin.edu.tr`
#
# ### Önemli Teslimat Yönergeleri
# * Dosyanızı **İsim\_Soyisim\_Numara\_AraSinav.ipynb** olarak kaydediniz. (Örnek: `Mustafa_Yilmaz_1607000_AraSinav.ipynb`)
# * Sınav süresi bitiminden önce yukarıdaki e-posta adresine **ek dosya** olarak gönderiniz.
# * **BULUT BAĞLANTISI (Google Drive, OneDrive vb.) KESİNLİKLE KABUL EDİLMEZ.** Colab kullanıyorsanız, dosyayı indirip e-posta eki olarak gönderiniz.
#
# ### Sınav Kuralları
# * **Üretken Yapay Zeka (ChatGPT, Gemini vb.) kullanımı ve bireysel iletişim kurmak yasaktır.**
# * Bu kurala uymayan öğrencilerin sınavı geçersiz sayılacaktır.
#
# ---
#
# ### Öğrenim Çıktıları (ÖÇ) - Bu Sınavda Değerlendirilecek Kazanımlar
#
# | ÖÇ No | Kazanım Açıklaması | İlgili Soru(lar) |
# | :---: | :--- | :---: |
# | **1** | Ham veriler üzerinde ön işleme (eksik veri doldurma/imputing, kategorik veri dönüştürme/encoding) adımlarını uygular. | Soru 1, Soru 2 |
# | **2** | Sınıflandırma ve regresyon problemleri için uygun makine öğrenmesi modellerini tanımlar, bu modelleri Python ile eğitir ve uygular. | Soru 2, Soru 3 |
# | **3** | Geliştirdiği modellerin performansını uygun istatistiksel ölçütlerle değerlendirir ve yorumlar. | Soru 1 |
# | **4** | CBS ve Uzaktan Algılama araçlarıyla oluşturulmuş bir veri seti üzerinde veri bilimi uygulaması geliştirir ve sonuçları analiz eder. | Soru 1 |
#
# ---

# %% [markdown]
# ### Soru 1 (60 puan)
#
# `su_indeks.csv` dosyası, bir uydu görüntüsünden hesaplanmış farklı su indeksi değerlerini ayrı ayrı sütunlarda barındırmaktadır. Tüm sütunlardaki değerler -1 ve +1 aralığındadır. Dolayısıyla ölçeklendirmeye ya da encode edilmeye gerek yoktur.
#
# | Sütun  | Su İndeksi                                              |
# |---------|----------------------------------------------------------|
# | NDWI    | Normalized Difference Water Index                   |
# | NDTI     | Normalized Difference Turbidity Index                                |
# | TWI   | Triangle Water Index                          |
# | MBWI  | Multi-Band Water Index               |
# | WRI    | Water Ratio Index                     |
#
# Aşağıdaki listede isminize karşılık gelen bağımsız ve bağımlı değişken sütunlarını kullanacaksınız.
#
# | Öğrenci No       | Adı Soyadı                | Bağımsız Değişken    | Bağımlı Değişken       |
# |------------------|---------------------------|----------------------|------------------------|
# | 20160010         | AZAT GEDİKOĞLU      | NDWI                 | NDTI                   |
# | 21220590008        | AYTEKİN SARIER               | NDWI                 | TWI                    |
# | 22220590003         | FAHRİ YILDIRIM               | NDWI                 | MBWI                   |
# | 23220590013         | NUR IŞIK               | NDWI                 | WRI                    |
# | 23220590016         | FATİH BÜLBÜL               | NDTI                 | TWI                    |
#
#
#
# Sizden istenenler:
#
# a) Veri setinde boşluk (NaN) değer varlığını tespit ediniz. Varsa, sütun ortalama değerleri ile bu boşlukları doldurunuz.
#
# b)Tüm veri setinin korelasyon matrisi ısı haritasını görselleştiriniz.
#
# c) Size verilen bağımlı ve bağımsız değişkenleri ayıklayınız.
#
# ç) Veri setini %70 eğitim ve %30 test porsiyonlarına ayırınız.
#
# d) Eğitim verilerini kullanarak lineer bir regresör inşa ediniz.
#
# e) Test verileri üzerinde bu regresörün tahmin etmesini sağlayınız.
#
# f) Test verilerinin gerçek ve tahmin edilen değerlerini aynı çerçevede iki ayrı saçılım grafiği olarak gösteriniz. Gerçek değerler mavi renkli, tahmin edilen değerler ise kırmızı renkli noktalardan oluşsun. Lineer çizgi çizmeyiniz!
#
# f) Regresörün performansını MSE ve R2 metriklerini çağırarak ölçünüz. R2 sonucunu yorumlayınız.
#
# g) Lineer regresörün doğru denklemini yazdırınız.

# %%
#ÇÖZÜME BURADAN BAŞLAYINIZ.

# %% [markdown]
# ### SORU 2 (30 puan)
#
# `asker.xlsx` dosyası askerlerin memleketi, boyu, kilosu, bot numarası, saç rengi, yaşı ve mesleği gibi bilgileri içeren sütunlardan oluşmaktadır.
#
# İstenilenler:
#
# 1) Aşağıdaki tabloda isminizin yanında yazan sütun üzerinde encoding işlemi yapınız. `LabelEncoder` kullanınız. Öncesinde np.unique ile kategorileri göstermeyi unutmayınız.
#
# 2) Askerlerin boyu ve kilosu arasında korelasyon katsayısını hesaplayınız.

# %% [markdown]
# | Öğrenci No       | Adı Soyadı                | Encode Edilecek Sütun    |
# |------------------|---------------------------|----------------------|
# | 20160010         | AZAT GEDİKOĞLU      | memleket                 |
# | 21220590008        | AYTEKİN SARIER               | meslek                 |
# | 22220590003       | FAHRİ YILDIRIM               | sac_rengi                 |
# | 23220590013         | NUR IŞIK               | memleket                 |
# | 23220590016        | FATİH BÜLBÜL               | meslek                 |

# %%
#ÇÖZÜME BURADAN BAŞLAYINIZ.

# %% [markdown]
# ### Soru 3 (10 puan)
#
#
# Aşağıdaki tabloda verilen problemlerin her birinin **Regresyon** mu yoksa **Sınıflandırma** problemi mi olduğunu belirleyiniz. Lütfen ilgili sütuna cevabınızı yazınız.
#
# ---
#
# | No | Problem Tanımı | Cevap: Regresyon / Sınıflandırma |
# | :---: | :--- | :---: |
# | **i)** | Bir müşterinin demografik verilerine (yaş, gelir, geçmiş alışveriş sıklığı) dayanarak, gelecek ay yapacağı toplam **harcama miktarının tahmin edilmesi.** | CEVAP:  |
# | **ii)** | Bir kredi başvurusunun, başvuru sahibinin finansal geçmişine bakılarak, **"Onaylanacak"** veya **"Reddedilecek"** şeklinde etiketlenmesi. | CEVAP:  |
# | **iii)** | Bir aracın motor hacmi, kilometresi ve markasına göre **ikinci el satış fiyatının kestirilmesi.** | CEVAP:  |
# | **iv)** | Bir tıbbi görüntüdeki (MR, röntgen) tümörün **iyi huylu** mu yoksa **kötü huylu** mu olduğunun otomatik olarak belirlenmesi. | CEVAP:  |
# | **vi)** | Bir internet kullanıcısının özelliklerine bakılarak, o kullanıcının ait olduğu **"Genç Yetişkin", "Orta Yaşlı" veya "Emekli"** yaş grubunun tespit edilmesi. | CEVAP:  |
#
# ---
